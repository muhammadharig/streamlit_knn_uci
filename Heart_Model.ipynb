# %% [markdown]
# ## Import Library yang di butuhkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Analisis

# %%
# menampilkan dataset
df = pd.read_csv('Heart_Dataset.csv')
df.head(5)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# <table>
# <thead><tr>
# <th>Attribute</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><strong>Age</strong></td>
# <td>Age of a patient [years]</td>
# </tr>
# <tr>
# <td><strong>Sex</strong></td>
# <td>Gender of the patient [M: Male, F: Female]</td>
# </tr>
# <tr>
# <td><strong>ChestPain</strong></td>
# <td>chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]</td>
# </tr>
# <tr>
# <td><strong>RestingBP</strong></td>
# <td>Blood pressure in Hg (Normal blood pressure - 120/80 Hg)</td>
# </tr>
# <tr>
# <td><strong>Cholesterol</strong></td>
# <td>Serum cholestrol level in blood (Normal cholesterol level below for adults 200mg/dL)</td>
# </tr>
# <tr>
# <td><strong>FastingBS</strong></td>
# <td>Fasting Blood Sugar (Normal less than 100mg/dL for non diabetes for diabetes 100-125mg/dL)</td>
# </tr>
# <tr>
# <td><strong>RestingECG</strong></td>
# <td>resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of &gt; 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]</td>
# </tr>
# <tr>
# <td><strong>MaxHR</strong></td>
# <td>maximum heart rate achieved [Numeric value between 60 and 202]</td>
# </tr>
# <tr>
# <td><strong>ExerciseAngina</strong></td>
# <td>exercise-induced angina [Y: Yes, N: No]</td>
# </tr>
# <tr>
# <td><strong>Oldpeak</strong></td>
# <td>oldpeak = ST [Numeric value measured in depression]</td>
# </tr>
# <tr>
# <td><strong>ST_Slope</strong></td>
# <td>the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]</td>
# </tr>
# <tr>
# <td><strong>HeartDisease</strong></td>
# <td>output class [1: heart disease, 0: Normal]</td>
# </tr>
# </tbody>
# </table>

# %%
# menampilkan statistika deskriptif
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# menampilkan informasi dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# cek data null atau missing
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # EDA

# %%
# menampilkan pie chart heart disease

heart_disease_count = df['output'].value_counts()

# membuat pie chart
plt.pie(heart_disease_count, labels=['Yes', 'No'], autopct='%1.1f%%')
plt.title('Percentage of Heart Disease')

# menampilkan pie chart
plt.show()

# %%
# Menampilkan bar chart
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='output')
plt.title('Heart Disease')
plt.xlabel('output')
plt.ylabel('output')
# Out:
# Text(0, 0.5, 'output')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
plt.figure(figsize=(18,18))
plt.subplot(3,2,1)
plt.tight_layout()
sns.set_context('talk')
sns.histplot(data=df, x='age', hue="output",multiple="stack",palette='magma')
plt.title('Age vs HeartDisease')

plt.subplot(3,2,2)
plt.tight_layout()
sns.set_context('talk')
sns.histplot(data=df, x='trtbps', hue="output",multiple="stack",palette='magma')
plt.title('RestingBP vs HeartDisease')

plt.subplot(3,2,3)
plt.tight_layout()
sns.set_context('talk')
sns.histplot(data=df, x='chol', hue="output",multiple="stack",palette='magma')
plt.title('Cholesterol vs HeartDisease')

plt.subplot(3,2,4)
plt.tight_layout()
sns.set_context('talk')
sns.histplot(data=df, x='fbs', hue="output",multiple="stack",palette='magma')
plt.title('FastingBS vs HeartDisease')

plt.subplot(3,2,5)
plt.tight_layout()
sns.set_context('talk')
sns.histplot(data=df, x='thalachh', hue="output",multiple="stack",palette='magma')
plt.title('MaxHR vs HeartDisease')

plt.subplot(3,2,6)
plt.tight_layout()
sns.set_context('talk')
sns.histplot(data=df, x='oldpeak', hue="output",multiple="stack",palette='magma')
plt.title('oldpeak vs HeartDisease')
# Out:
# c:\Users\DGDEV\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DGDEV\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DGDEV\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.set()
df.hist(figsize=(10,10))
plt.show()

# %%
sns.pairplot(df,hue='output')
# Out:
# c:\Users\DGDEV\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DGDEV\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DGDEV\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# make heatmap to show all number of correlation
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
# menampilkan boxplot
plt.figure(figsize=(20, 20))
sns.boxplot(data=df)
plt.title('Boxplot')
plt.show()

# %%
# tampilkan boxplot thalachh
plt.figure(figsize=(5, 10))
sns.boxplot(data=df['thalachh'])
plt.title('Boxplot')
plt.show()

# %%
df[df.thalachh == 71]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 272   67    1   0     120   237    0        1        71     0      1.0    1
#
#      caa  thall  output
# 272    0      2       0

# %%
df.at[272,'thalachh']=None

# %%
df[df.thalachh == 71]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trtbps, chol, fbs, restecg, thalachh, exng, oldpeak, slp, caa, thall, output]
# Index: []

# %%
heart_disease_true_count = len(df.loc[df['output'] == 1])
heart_disease_false_count = len(df.loc[df['output'] == 0])

# %%
(heart_disease_true_count, heart_disease_false_count)
# Out:
# (165, 138)

# %%
#Missing value
print('total number of rows : {0}'.format(df.shape[0]))
print('total number of columns : {0}'.format(df.shape[1]))
# Out:
# total number of rows : 303
# total number of columns : 14

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
print('Banyak baris nilai nol untuk usia : {0}'.format(len(df.loc[df['age'] == 0])))
print('Banyak baris nilai nol untuk trtbps : {0}'.format(len(df.loc[df['trtbps'] == 0])))
print('Banyak baris nilai nol untuk chol : {0}'.format(len(df.loc[df['chol'] == 0])))
print('Banyak baris nilai nol untuk thalachh : {0}'.format(len(df.loc[df['thalachh'] == 0])))
print('Banyak baris nilai nol untuk oldpeak : {0}'.format(len(df.loc[df['oldpeak'] == 0])))
print('Banyak baris nilai nol untuk caa : {0}'.format(len(df.loc[df['caa'] == 0])))
print('Banyak baris nilai nol untuk thall : {0}'.format(len(df.loc[df['thall'] == 0])))
print('Banyak baris nilai nol untuk output : {0}'.format(len(df.loc[df['output'] == 0])))
print('Banyak baris nilai nol untuk sex : {0}'.format(len(df.loc[df['sex'] == 0])))
print('Banyak baris nilai nol untuk cp : {0}'.format(len(df.loc[df['cp'] == 0])))
print('Banyak baris nilai nol untuk restecg : {0}'.format(len(df.loc[df['restecg'] == 0])))
print('Banyak baris nilai nol untuk fbs : {0}'.format(len(df.loc[df['fbs'] == 0])))
print('Banyak baris nilai nol untuk exng : {0}'.format(len(df.loc[df['exng'] == 0])))
print('Banyak baris nilai nol untuk slp : {0}'.format(len(df.loc[df['slp'] == 0])))
# Out:
# Banyak baris nilai nol untuk usia : 0
# Banyak baris nilai nol untuk trtbps : 0
# Banyak baris nilai nol untuk chol : 0
# Banyak baris nilai nol untuk thalachh : 0
# Banyak baris nilai nol untuk oldpeak : 99
# Banyak baris nilai nol untuk caa : 175
# Banyak baris nilai nol untuk thall : 2
# Banyak baris nilai nol untuk output : 138
# Banyak baris nilai nol untuk sex : 96
# Banyak baris nilai nol untuk cp : 143
# Banyak baris nilai nol untuk restecg : 147
# Banyak baris nilai nol untuk fbs : 258
# Banyak baris nilai nol untuk exng : 204
# Banyak baris nilai nol untuk slp : 21

# %%
df.head(5)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0     150.0     0      2.3    0
# 1   37    1   2     130   250    0        1     187.0     0      3.5    0
# 2   41    0   1     130   204    0        0     172.0     0      1.4    2
# 3   56    1   1     120   236    0        1     178.0     0      0.8    2
# 4   57    0   0     120   354    0        1     163.0     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
data = df.copy()

# %%
avg_oldpeak = data['oldpeak'].mean()

# %%
# replace avg to column
data['oldpeak'].replace(0, avg_oldpeak, inplace=True)

# %%
print('Banyak baris nilai nol untuk usia : {0}'.format(len(data.loc[data['age'] == 0])))
print('Banyak baris nilai nol untuk trtbps : {0}'.format(len(data.loc[data['trtbps'] == 0])))
print('Banyak baris nilai nol untuk chol : {0}'.format(len(data.loc[data['chol'] == 0])))
print('Banyak baris nilai nol untuk thalachh : {0}'.format(len(data.loc[data['thalachh'] == 0])))
print('Banyak baris nilai nol untuk oldpeak : {0}'.format(len(data.loc[data['oldpeak'] == 0])))
print('Banyak baris nilai nol untuk caa : {0}'.format(len(data.loc[data['caa'] == 0])))
print('Banyak baris nilai nol untuk thall : {0}'.format(len(data.loc[data['thall'] == 0])))
print('Banyak baris nilai nol untuk output : {0}'.format(len(data.loc[data['output'] == 0])))
print('Banyak baris nilai nol untuk sex : {0}'.format(len(data.loc[data['sex'] == 0])))
print('Banyak baris nilai nol untuk cp : {0}'.format(len(data.loc[data['cp'] == 0])))
print('Banyak baris nilai nol untuk restecg : {0}'.format(len(data.loc[data['restecg'] == 0])))
print('Banyak baris nilai nol untuk fbs : {0}'.format(len(data.loc[data['fbs'] == 0])))
print('Banyak baris nilai nol untuk exng : {0}'.format(len(data.loc[data['exng'] == 0])))
print('Banyak baris nilai nol untuk slp : {0}'.format(len(data.loc[data['slp'] == 0])))
# Out:
# Banyak baris nilai nol untuk usia : 0
# Banyak baris nilai nol untuk trtbps : 0
# Banyak baris nilai nol untuk chol : 0
# Banyak baris nilai nol untuk thalachh : 0
# Banyak baris nilai nol untuk oldpeak : 0
# Banyak baris nilai nol untuk caa : 175
# Banyak baris nilai nol untuk thall : 2
# Banyak baris nilai nol untuk output : 138
# Banyak baris nilai nol untuk sex : 96
# Banyak baris nilai nol untuk cp : 143
# Banyak baris nilai nol untuk restecg : 147
# Banyak baris nilai nol untuk fbs : 258
# Banyak baris nilai nol untuk exng : 204
# Banyak baris nilai nol untuk slp : 21

# %% [markdown]
# # Membuat Model

# %%
from sklearn.model_selection import train_test_split

X = data.drop('output', axis=1)
y = data['output']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: output, Length: 303, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng   oldpeak  slp  \
# 132   42    1   1     120   295    0        1     162.0     0  1.039604    2
# 202   58    1   0     150   270    0        0     111.0     1  0.800000    2
# 196   46    1   2     150   231    0        1     147.0     0  3.600000    1
# 75    55    0   1     135   250    0        0     161.0     0  1.400000    1
# 176   60    1   0     117   230    1        1     160.0     1  1.400000    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...       ...  ...
# 188   50    1   2     140   233    0        1     163.0     0  0.600000    1
# 71    51    1   2      94   227    0        1     154.0     1  1.039604    2
# 106   69    1   3     160   234    1        0     131.0     0  0.100000    1
# 270   46    1   0     120   249    0        0     144.0     0  0.800000    2
# 102   63    0   1     140   195    0        1     179.0     0  1.039604    2
#
#      caa  thall
# 132    0      2
# ...

# %%
X_train.shape
# Out:
# (242, 13)

# %%
y_train.shape
# Out:
# (242,)

# %%
X_test
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng   oldpeak  slp  \
# 179   57    1   0     150   276    0        0     112.0     1  0.600000    1
# 228   59    1   3     170   288    0        0     159.0     0  0.200000    1
# 111   57    1   2     150   126    1        1     173.0     0  0.200000    2
# 246   56    0   0     134   409    0        0     150.0     1  1.900000    1
# 60    71    0   2     110   265    1        0     130.0     0  1.039604    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...       ...  ...
# 249   69    1   2     140   254    0        0     146.0     0  2.000000    1
# 104   50    1   2     129   196    0        1     163.0     0  1.039604    2
# 300   68    1   0     144   193    1        1     141.0     0  3.400000    1
# 193   60    1   0     145   282    0        0     142.0     1  2.800000    1
# 184   50    1   0     150   243    0        0     128.0     0  2.600000    1
#
#      caa  thall
# 179    1      1
# ...

# %%
y_train
# Out:
# 132    1
# 202    0
# 196    0
# 75     1
# 176    0
#       ..
# 188    0
# 71     1
# 106    1
# 270    0
# 102    1
# Name: output, Length: 242, dtype: int64

# %% [markdown]
# # Training

# %%
# membuat model knn
from sklearn.neighbors import KNeighborsClassifier

# Create the KNN model
knn_model = KNeighborsClassifier(
    
)

# Train the model
knn_model.fit(X_train, y_train)

# Predict on test data
y_pred = knn_model.predict(X_test)

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_prediction = knn_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, knn_prediction))
# Out:
# [[19 10]
#  [ 8 24]]

# %%
print(classification_report(y_test,knn_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68        29
#            1       0.71      0.75      0.73        32
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.70      0.70        61
# weighted avg       0.70      0.70      0.70        61
